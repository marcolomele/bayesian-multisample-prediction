# %%
import tarfile
import csv
import os

path = '/Users/marcolomele/Documents/Repos/bayesian-multisample/data/twenty+newsgroups/20_newsgroups.tar.gz'

# Extract if needed
with tarfile.open(path, 'r:gz') as tar:
    tar.extractall('extracted_data')

# Then process the extracted files into CSV
# (structure depends on what's inside)
